# %%
import pandas as pd
import numpy as np
from collections import Counter
from rapidfuzz import process, fuzz
from sklearn.preprocessing import MinMaxScaler
import ast
import re
import os
import nltk

# %%
# Env variable NLTK
nltk_data_path = os.getenv('NLTK_DATA')

if nltk_data_path:
    nltk.data.path.append(nltk_data_path)
else:
    print("⚠️ NLTK_DATA environment variable not set. Using default paths.")

from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
# Out:
# ⚠️ NLTK_DATA environment variable not set. Using default paths.

# %%
pd.set_option('display.max_rows', None)     
pd.set_option('display.max_columns', None)

# %%
data_dir = "../../data"

# %%
data_dir = "../../data"

interactions = pd.read_csv(f"{data_dir}/RAW_interactions.csv")
recipes = pd.read_csv(f"{data_dir}/RAW_recipes.csv")
pp_users = pd.read_csv(f"{data_dir}/PP_users.csv") #optional
pp_recipes = pd.read_csv(f"{data_dir}/PP_recipes.csv")  #optional

# %% [markdown]
# # Cleaning datasets

# %%
def check_missing_values(dataframe, df_name="DataFrame"):
    """
    Check missing values in a dataframe and calculate the percentage of missing values
    """
    
    size = dataframe.size
    missing_values = dataframe.isnull().sum()

    # Calculate missing percentage for each feature
    missing_percentage = (missing_values / len(dataframe)) * 100
    
    missing_summary = pd.DataFrame({
        'Column': missing_values.index,
        'Missing Values': missing_values.values,
        'Missing Percentage': missing_percentage.values.round(2)
    })

    missing_summary = missing_summary.sort_values('Missing Percentage', ascending=False)

    total_missing = missing_values.sum()
    total_missing_percentage = (total_missing / size) * 100

    print(f"\n--- {df_name} Missing Values Analysis ---")
    print(f"Total cells: {size}")
    print(f"Total missing values: {total_missing} ({total_missing_percentage:.2f}%)")
    print("\nColumn-wise missing values:")
    display(missing_summary)

    missing_columns = missing_summary[missing_summary['Missing Values'] > 0]
    if len(missing_columns) > 0:
        print("\nColumns with missing values:")
        display(missing_columns)
    else:
        print("\nNo missing values found in any column.")

# %%
check_missing_values(interactions, "Interactions")
check_missing_values(recipes, "Recipes")
check_missing_values(pp_users, "Preprocessed Users")
check_missing_values(pp_recipes, "Preprocessed Recipes")
# Out:
# --- Interactions Missing Values Analysis ---
# Total cells: 5661835
# Total missing values: 169 (0.00%)
#
# Column-wise missing values:
#       Column  Missing Values  Missing Percentage
# 4     review             169                0.01
# 0    user_id               0                0.00
# 1  recipe_id               0                0.00
# 2       date               0                0.00
# 3     rating               0                0.00
# Columns with missing values:
#    Column  Missing Values  Missing Percentage
# 4  review             169                0.01
# --- Recipes Missing Values Analysis ---
# Total cells: 2779644
# Total missing values: 4980 (0.18%)
#
# Column-wise missing values:
#             Column  Missing Values  Missing Percentage
# 9      description            4979                2.15
# 0             name               1                0.00
# 1               id               0                0.00
# 2          minutes               0                0.00
# 3   contributor_id               0                0.00
# 4        submitted               0                0.00
# 5             tags               0                0.00
# 6        nutrition               0                0.00
# 7          n_steps               0                0.00
# 8            steps               0                0.00
# 10     ingredients               0                0.00
# 11   n_ingredients               0                0.00
# Columns with missing values:
#         Column  Missing Values  Missing Percentage
# 9  description            4979                2.15
# 0         name               1                0.00
# --- Preprocessed Users Missing Values Analysis ---
# Total cells: 150456
# Total missing values: 0 (0.00%)
#
# Column-wise missing values:
#        Column  Missing Values  Missing Percentage
# 0           u               0                 0.0
# 1  techniques               0                 0.0
# 2       items               0                 0.0
# 3     n_items               0                 0.0
# 4     ratings               0                 0.0
# 5   n_ratings               0                 0.0
# No missing values found in any column.
#
# --- Preprocessed Recipes Missing Values Analysis ---
# Total cells: 1426120
# Total missing values: 0 (0.00%)
#
# Column-wise missing values:
#               Column  Missing Values  Missing Percentage
# 0                 id               0                 0.0
# 1                  i               0                 0.0
# 2        name_tokens               0                 0.0
# 3  ingredient_tokens               0                 0.0
# 4       steps_tokens               0                 0.0
# 5         techniques               0                 0.0
# 6      calorie_level               0                 0.0
# 7     ingredient_ids               0                 0.0
# No missing values found in any column.

# %% [markdown]
# ## Cleaning missing values

# %%
interactions['review'] = interactions['review'].fillna("No review provided")
recipes['description'] = recipes['description'].fillna("No description available")
recipes = recipes.dropna(subset=['name'])

# %%
check_missing_values(interactions, "Interactions (Clean)")
check_missing_values(recipes, "Recipes (Clean)")
# Out:
# --- Interactions (Clean) Missing Values Analysis ---
# Total cells: 5661835
# Total missing values: 0 (0.00%)
#
# Column-wise missing values:
#       Column  Missing Values  Missing Percentage
# 0    user_id               0                 0.0
# 1  recipe_id               0                 0.0
# 2       date               0                 0.0
# 3     rating               0                 0.0
# 4     review               0                 0.0
# No missing values found in any column.
#
# --- Recipes (Clean) Missing Values Analysis ---
# Total cells: 2779632
# Total missing values: 0 (0.00%)
#
# Column-wise missing values:
#             Column  Missing Values  Missing Percentage
# 0             name               0                 0.0
# 1               id               0                 0.0
# 2          minutes               0                 0.0
# 3   contributor_id               0                 0.0
# 4        submitted               0                 0.0
# 5             tags               0                 0.0
# 6        nutrition               0                 0.0
# 7          n_steps               0                 0.0
# 8            steps               0                 0.0
# 9      description               0                 0.0
# 10     ingredients               0                 0.0
# 11   n_ingredients               0                 0.0
# No missing values found in any column.

# %% [markdown]
# ## Recipe Dataset

# %%
recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 231636 entries, 0 to 231636
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            231636 non-null  object
#  1   id              231636 non-null  int64
#  2   minutes         231636 non-null  int64
#  3   contributor_id  231636 non-null  int64
#  4   submitted       231636 non-null  object
#  5   tags            231636 non-null  object
#  6   nutrition       231636 non-null  object
#  7   n_steps         231636 non-null  int64
#  8   steps           231636 non-null  object
#  9   description     231636 non-null  object
#  10  ingredients     231636 non-null  object
#  11  n_ingredients   231636 non-null  int64
# dtypes: int64(5), object(7)
# memory usage: 23.0+ MB

# %%
#Convert to stringified lists
recipes['ingredients'] = recipes['ingredients'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
recipes['tags'] = recipes['tags'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
recipes['nutrition'] = recipes['nutrition'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
recipes['submitted'] = pd.to_datetime(recipes['submitted'])

# %% [markdown]
# ### Extract nutrition features from list values --> Food.com Kaggle for reference

# %%
def split_nutrition(nutrition_list):
    """
        Extract nutrition from list of values
    """
    return pd.Series({
        'calories': nutrition_list[0],
        'total_fat_pdv': nutrition_list[1],
        'sugar_pdv': nutrition_list[2],
        'sodium_pdv': nutrition_list[3],
        'protein_pdv': nutrition_list[4],
        'saturated_fat_pdv': nutrition_list[5],
        'carbs_pdv': nutrition_list[6]
    })

# %%
nutrition_df = recipes['nutrition'].apply(split_nutrition)
recipes = pd.concat([recipes, nutrition_df], axis=1)

# %% [markdown]
# ### Normalize

# %%
# Scale features
scaler = MinMaxScaler()
pdv_cols = ['total_fat_pdv', 'sugar_pdv', 'sodium_pdv', 'protein_pdv', 'saturated_fat_pdv', 'carbs_pdv']
recipes[[f'{col}_norm' for col in pdv_cols]] = scaler.fit_transform(recipes[pdv_cols])
recipes['minutes_normalized'] = scaler.fit_transform(recipes[['minutes']])
recipes['n_steps_norm'] = scaler.fit_transform(recipes[['n_steps']])

# %% [markdown]
# ### Normalize ingredients

# %% [markdown]
# We clean up each ingredient name in your dataset by:
#
# - Lowercasing it
# - Removing punctuation
# - Removing numbers
# - Lemmatizing to fix plural/singular differences (e.g., "onions" → "onion")
# - Remove prep words: 'chopped', 'diced', 'sliced', 'minced', 'shredded', 'crushed', 'grated',
#     'ground', 'peeled', 'fresh', 'organic', 'frozen', 'raw'

# %%
lemmatizer = WordNetLemmatizer()

# %%
prep_words = [
    'chopped', 'diced', 'sliced', 'minced', 'shredded', 'crushed', 'grated',
    'ground', 'peeled', 'fresh', 'organic', 'frozen', 'raw', 'whole'
]

# %%
def clean_and_normalize(ingredient):
    ingredient = ingredient.lower().strip()
    ingredient = re.sub(r'[^\w\s]', '', ingredient)
    ingredient = re.sub(r'\d+', '', ingredient)
    words = ingredient.split()
    words = [word for word in words if word not in prep_words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    normalized_ingredient = " ".join(lemmatized_words)
    return normalized_ingredient

# %%
recipes['cleaned_ingredients'] = recipes['ingredients'].apply(
    lambda ing_list: [clean_and_normalize(ing) for ing in ing_list])

# %%
recipes[['name', 'ingredients','cleaned_ingredients']].head(50)
# Out:
#                                                  name  \
# 0          arriba   baked winter squash mexican style
# 1                    a bit different  breakfast pizza
# 2                           all in the kitchen  chili
# 3                                  alouette  potatoes
# 4                  amish  tomato ketchup  for canning
# 5                             apple a day  milk shake
# 6                               aww  marinated olives
# 7                      backyard style  barbecued ribs
# 8                            bananas 4 ice cream  pie
# 9                             beat this  banana bread
# 10                        berry  good sandwich spread
# 11                      better than sex  strawberries
# 12                    better then bush s  baked beans
# 13                         boat house  collard greens
# 14                            calm your nerves  tonic
# 15                   chicken lickin  good  pork chops
# 16                                     chile rellenos
# 17                                     chinese  candy
# 18                                 chinese  chop suey
# 19                  cream  of cauliflower soup  vegan
# 20                             cream  of spinach soup
# 21                      cream  of spinach soup  vegan
# 22                            crispy crunchy  chicken
# 23                         deep fried dessert thingys
# 24                    easiest ever  hollandaise sauce
# 25                   emotional balance  spice mixture
# 26                        fool the meat eaters  chili
# 27                              forgotten  minestrone
# 28                                    fried  potatoes
# 29              george s at the cove  black bean soup
# 30                        get the sensation  brownies
# 31                     global gourmet  taco casserole
# 46  [sandwich bun, good seasonings italian salad d...
# 47  [shortening, icing sugar, vanilla, all-purpose...
# 48  [yellow cake mix, vanilla instant pudding mix,...
# 49  [whole kernel corn, onion, red bell pepper, bu...
#
#                                   cleaned_ingredients
# 0   [winter squash, mexican seasoning, mixed spice...
# 1   [prepared pizza crust, sausage patty, egg, mil...
# 2   [beef, yellow onion, tomato, tomato paste, tom...
# 3   [spreadable cheese with garlic and herb, new p...
# 4   [tomato juice, apple cider vinegar, sugar, sal...
# 5   [milk, vanilla ice cream, apple juice concentr...
# 6   [fennel seed, green olive, ripe olive, garlic,...
# 7   [pork sparerib, soy sauce, garlic, ginger, chi...
# 8   [chocolate sandwich style cooky, chocolate syr...
# 9   [sugar, unsalted butter, banana, egg, lemon ju...
# 10  [berry cranberry sauce, sour cream, prepared h...
# 11  [vanilla wafer, butter, powdered sugar, egg, w...
# 12  [great northern bean, chicken bouillon cube, d...
# 13  [collard green, brown sugar, molasses, hot sau...
# 14  [gentian root, scullcap herb, burnet root, woo...
# 15  [lean pork chop, flour, salt, dry mustard, gar...
# 16  [egg roll wrap, green chilies, cheese, cornsta...
# 17  [butterscotch chip, chinese noodle, salted pea...
# 18  [celery, onion, pork, soy sauce, beef broth, c...
# 19  [canola oil, onion, garlic, cauliflower, potat...
# 20  [water, salt, boiling potato, spinach leaf, un...
# 21  [onion, scallion, apple juice, olive oil, spin...
# 22  [boneless skinless chicken breast half, conden...
# 23  [allpurpose flour, granulated sugar, baking po...
# 24  [butter, lemon juice of, salt, white pepper, e...
# 25  [black pepper, ginger, coriander, cumin, turme...
# 26  [vegetarian beef, garlic, onion, jalapeno, gre...
# 27  [beef stew meat, water, tomato, beef bouillon ...
# 28                  [red potato, margarine, rosemary]
# 29  [unsalted butter, carrot, onion, celery, brocc...
# 30  [butter, sugar, vanilla, egg, allpurpose flour...
# 31  [beef, onion, tomato sauce, taco sauce, salt, ...
# 32     [butter, dry ranch dressing mix, french bread]
# 33  [venison, egg substitute, nonfat powdered milk...
# 34            [milk, juice concentrate, plain yogurt]
# 35  [low sodium chicken broth, tomato, zucchini, c...
# 36  [spinach, egg, salt, black pepper, onion, shar...
# 37  [red potato, green onion, pimento, fatfree may...
# 38  [spinach, egg, garlic powder, soft breadcrumb,...
# 39  [beef, onion, vegetable, cream of mushroom sou...
# 40  [angel hair pasta, toasted sesame oil, soy sau...
# 41  [allpurpose flour, buckwheat flour, unsweetene...
# 42  [allpurpose flour, buckwheat flour, unsweetene...
# 43  [beef, sugar, prepared yellow mustard, beer, c...
# 44  [tricolor spiral pasta, dill pickle, ripe oliv...
# 45  [french fry, oil, salt freshly black pepper, p...
# 46  [sandwich bun, good seasoning italian salad dr...
# 47  [shortening, icing sugar, vanilla, allpurpose ...
# 48  [yellow cake mix, vanilla instant pudding mix,...
# 49  [kernel corn, onion, red bell pepper, butter, ...

# %%
#ONLY IF WE HAVE TIME, FOR NOW, IT WOULD COMPLICATE THE PROJECT
def find_similar(base, ingredient_list, threshold=85, limit=10, max_words=3):
    """
    Find similar ingredient names to a base ingredient.
    """
    results = process.extract(base, ingredient_list, scorer=fuzz.token_set_ratio, limit=limit)
    matches = [r for r in results if r[1] >= threshold]
    
    filtered = []
    
    for match in matches:
        ingredient = match[0]
        word_count = len(ingredient.split())
        
        if word_count <= max_words:
            filtered.append(match)
    
    return filtered

# %% [markdown]
# ### Cleaning tags

# %%
all_tags = [tag for tags in recipes['tags'] for tag in tags]
tag_counts = Counter(all_tags)
for tag, count in tag_counts.items():
    print(f"{tag}: {count}")
# Out:
# 60-minutes-or-less: 69990
# time-to-make: 225325
# course: 218147
# main-ingredient: 170446
# cuisine: 91165
# preparation: 230545
# occasion: 114145
# north-american: 48479
# side-dishes: 26902
# vegetables: 53814
# mexican: 6694
# easy: 126061
# fall: 7754
# holiday-event: 34920
# vegetarian: 35651
# winter: 7654
# dietary: 165090
# christmas: 8145
# seasonal: 21933
# squash: 3696
# 30-minutes-or-less: 55077
# breakfast: 13655
# main-dish: 71786
# pork: 12692
# american: 31179
# oven: 31180
# kid-friendly: 27074
# pizza: 1505
# northeastern-united-states: 2566
# meat: 56042
# equipment: 70436
# chili: 1693
# crock-pot-slow-cooker: 6608
# 4-hours-or-less: 49497
# eggs-dairy: 30142
# potatoes: 10293
# dinner-party: 37561
# easter: 2368
# cheese: 15147
# stove-top: 22095
# new-years: 2487
# thanksgiving: 4357
# independence-day: 2359
# st-patricks-day: 828
# valentines-day: 2680
# inexpensive: 32618
# brunch: 18927
# superbowl: 1865
# presentation: 24470
# served-hot: 12061
# weeknight: 20948
# canning: 1013
# condiments-etc: 11874
# heirloom-historical: 4575
# amish-mennonite: 214
# number-of-servings: 58949
# technique: 11540
# 15-minutes-or-less: 43933
# low-protein: 32521
# 5-ingredients-or-less: 35466
# beverages: 11124
# fruit: 31324
# low-sodium: 43348
# shakes: 784
# low-calorie: 36429
# low-in-something: 85775
# apples: 4943
# served-cold: 7558
# 3-steps-or-less: 44932
# appetizers: 20379
# canadian: 4572
# vegan: 10012
# freezer: 1573
# south-west-pacific: 3934
# hawaiian: 444
# spicy: 8225
# copycat: 2314
# pork-ribs: 532
# super-bowl: 224
# novelty: 4632
# taste-mood: 52143
# savory: 10544
# sweet: 10543
# pies-and-tarts: 4766
# desserts: 43203
# lunch: 23800
# snacks: 7159
# no-cook: 6194
# refrigerator: 4833
# frozen-desserts: 1955
# pies: 3210
# chocolate: 9389
# breads: 14537
# oamc-freezer-make-ahead: 4232
# quick-breads: 5652
# tropical-fruit: 5335
# bananas: 2098
# healthy: 40340
# 1-day-or-more: 2138
# comfort-food: 26136
# berries: 5831
# strawberries: 2231
# beans: 9533
# potluck: 10699
# to-go: 18524
# greens: 4038
# collard-greens: 123
# pork-chops: 1590
# southwestern-united-states: 3536
# deep-fry: 1114
# candy: 2372
# beef: 17074
# one-dish-meal: 16807
# lactose: 4105
# bisques-cream-soups: 1808
# soups-stews: 11360
# spring: 4072
# food-processor-blender: 4844
# free-of-something: 11804
# cauliflower: 1154
# small-appliance: 8522
# beginner-cook: 35561
# low-cholesterol: 36743
# low-carb: 42189
# healthy-2: 26619
# spinach: 1893
# low-saturated-fat: 31378
# crawfish: 94
# oatmeal: 51
# reynolds-wrap: 70
# malaysian: 119
# duck: 169
# rosh-hashanah: 47
# nepalese: 53
# eggplant: 97
# goose: 19
# icelandic: 44
# veggie-burgers: 41
# mothers-day: 49
# mashed-potatoes: 102
# chocolate-chip-cookies: 72
# vietnamese: 351
# elk: 34
# oysters: 178
# palestinian: 92
# rabbit: 58
# norwegian: 199
# lobster: 197
# main-dish-beef: 3
# beef-crock-pot: 1
# pot-roast: 1
# hunan: 31
# austrian: 170
# halloween-cocktails: 4
# libyan: 40
# april-fools-day: 7
# beef-organ-meats: 144
# beef-liver: 91
# angolan: 13
# korean: 253
# cantonese: 90
# whole-duck: 44
# halloween-cupcakes: 13
# halloween-cakes: 11
# ragu-recipe-contest: 43
# macaroni-and-cheese: 75
# trout: 127
# irish-st-patricks-day: 1
# bass: 82
# beijing: 18
# quail: 18
# pickeral: 7
# main-dish-chicken: 3
# bear: 6
# brewing: 60
# cambodian: 46
# beef-kidney: 6
# beef-sauces: 1
# spaghetti-sauce: 2
# heirloom-historical-recipes: 2
# pot-pie: 27
# dips-lunch-snacks: 11
# pressure-canning: 41
# main-dish-pork: 5
# pork-loins-roast: 1
# quiche: 27
# sugar-cookies: 21
# venezuelan: 48
# octopus: 14
# side-dishes-beans: 2
# beans-side-dishes: 2
# baked-beans: 1
# snacks-kid-friendly: 1
# snacks-sweet: 1
# duck-breasts: 53
# main-dish-pasta: 1
# pasta-salad: 2
# pasta-elbow-macaroni: 9
# namibian: 6
# mushroom-soup: 1
# beef-barley-soup: 1
# pork-crock-pot: 1
# crock-pot-main-dish: 2
# desserts-fruit: 1
# desserts-easy: 1
# lasagne: 1
# laotian: 16
# cabbage: 1
# prepared-potatoes: 5
# middle-eastern-main-dish: 1
# high-in-something-diabetic-friendly: 1
# dips-summer: 1
# black-bean-soup: 1
# bean-soup: 1
# served-hot-new-years: 1
# ham-and-bean-soup: 1
# lamb-sheep-main-dish: 1
# mongolian: 13
# for-large-groups-holiday-event: 1
# stews-poultry: 1
# pasta-rice-and-grains-elbow-macaroni: 1
# pork-loin: 1
# cranberry-sauce: 1
# marinara-sauce: 1
# breakfast-casseroles: 1
# breakfast-potatoes: 1
# main-dish-seafood: 1
# shrimp-main-dish: 1
# pumpkin-bread: 1
# bread-pudding: 1
# less_thansql:name_topics_of_recipegreater_than: 1
# chicken-crock-pot: 1
# chicken-stews: 1
# chicken-stew: 1
# Throw the ultimate fiesta with this sopaipillas recipe from Food.com.: 1
# roast-beef-main-dish: 1
# roast-beef-comfort-food: 1

# %%
junk_tags = [
    'low-in-something', 'high-in-something', 'dietary', 'preparation', 'course',
    'occasion', 'equipment', 'main-ingredient', 'presentation', 'technique'
]

recipes['tags'] = recipes['tags'].apply(lambda tags: [tag for tag in tags if tag not in junk_tags])

# %%
# Lowercase, strip whitespace, and replace hyphens with underscores
recipes['tags'] = recipes['tags'].apply(
    lambda tags: [tag.lower().replace('-', '_').strip() for tag in tags]
)

# %% [markdown]
# ## Interaction Dataset

# %%
interactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1132367 entries, 0 to 1132366
# Data columns (total 5 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user_id    1132367 non-null  int64
#  1   recipe_id  1132367 non-null  int64
#  2   date       1132367 non-null  object
#  3   rating     1132367 non-null  int64
#  4   review     1132367 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 43.2+ MB

# %%
interactions['date'] = pd.to_datetime(interactions['date'])

# %%
interactions = interactions.sort_values(by='date', ascending=False)

#Keep the latest interaction (rating/review) for each user-recipe pair
interactions_latest = interactions.drop_duplicates(subset=['user_id', 'recipe_id'])

# %%
interactions['rating'] = interactions['rating'].clip(lower=1, upper=5)

# %% [markdown]
# Perhaps, it could be useful to review later do a sentimental analysis on the review

# %% [markdown]
# ## pp_users dataset

# %%
pp_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25076 entries, 0 to 25075
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   u           25076 non-null  int64
#  1   techniques  25076 non-null  object
#  2   items       25076 non-null  object
#  3   n_items     25076 non-null  int64
#  4   ratings     25076 non-null  object
#  5   n_ratings   25076 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 1.1+ MB

# %%
#Convert to stringified lists
pp_users['techniques'] = pp_users['techniques'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
pp_users['items'] = pp_users['items'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
pp_users['ratings'] = pp_users['ratings'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
pp_users['techniques_array'] = pp_users['techniques'].apply(lambda x: np.array(x))

# %%
#confirm consistency of the data
assert all(pp_users['n_items'] == pp_users['items'].apply(len))
assert all(pp_users['n_ratings'] == pp_users['ratings'].apply(len))

# %% [markdown]
# ## pp_recipe dataset

# %%
pp_recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178265 entries, 0 to 178264
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 178265 non-null  int64
#  1   i                  178265 non-null  int64
#  2   name_tokens        178265 non-null  object
#  3   ingredient_tokens  178265 non-null  object
#  4   steps_tokens       178265 non-null  object
#  5   techniques         178265 non-null  object
#  6   calorie_level      178265 non-null  int64
#  7   ingredient_ids     178265 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 10.9+ MB

# %%
assert pp_recipes['id'].is_unique

# %%
#Convert to stringified lists
pp_recipes['name_tokens'] = pp_recipes['name_tokens'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
pp_recipes['ingredient_tokens'] = pp_recipes['ingredient_tokens'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
pp_recipes['steps_tokens'] = pp_recipes['steps_tokens'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
pp_recipes['techniques'] = pp_recipes['techniques'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
pp_recipes['ingredient_ids'] = pp_recipes['ingredient_ids'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %% [markdown]
# ## Export clean data to pkl file

# %%
recipes.to_pickle(f'{data_dir}/recipes_clean.pkl')
interactions.to_pickle(f'{data_dir}/interactions_clean.pkl')
pp_users.to_pickle(f'{data_dir}/pp_users_clean.pkl')
pp_recipes.to_pickle(f'{data_dir}/pp_recipes_clean.pkl')
